# %%
#import used libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read csv file
df = pd.read_csv('Upwork.csv')
#split data into two dataframes , S and E
df_s = pd.read_csv('df_s.csv')
df_e = pd.read_csv('df_e.csv')

#needed for plotting
x = [1,2,4,8,16]
y1 = dict()
y2 = dict()

# extracting y1 and y2 from dataframes
for _type in df_s['Type']:
    data = []
    for i in x:
        num = df_s[df_s['Type'] == _type].loc[:,str(i)].values.tolist()[0]
        data.append(num)
    y1[_type] = data 

for _type in df_s['Type']:
    data = []
    for i in x:
        num = df_e[df_e['Type'] == _type].loc[:,str(i)].values.tolist()[0]
        data.append(num)
    y2[_type] = data

# %%
figure,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(x,y1["Half"],linestyle = 'dotted',label = 'Half')
axis[0].plot(x,y1["Original"])
axis[0].plot(x,y1["Double"],linestyle = 'dashed',label = 'Double')
axis[0].legend(['Half','Original','Double'])



axis[1].plot(x,y2["Half"],linestyle = 'dotted',label = 'Half')
axis[1].plot(x,y2["Original"])
axis[1].plot(x,y2["Double"],linestyle = 'dashed',label = 'Double')
axis[1].legend(['Half','Original','Double']);

# %%
plt.xlabel('Processes')
plt.ylabel('Speedup')
plt.plot(x,y1["Half"],linestyle = 'dotted',label = 'Half')
plt.plot(x,y1["Original"])
plt.plot(x,y1["Double"],linestyle = 'dashed',label = 'Double')
plt.legend(['Half','Original','Double']);

# %% [markdown]
# # Processes - Speed Up Relation
# > Half seems to be not responding to the increase in processes and starts flatenning at 8 processes,
# Original has better speed up but it decreases with a slower rate than Half,
# Double seems to have a linear correlation between Processes and speed up

# %%
plt.xlabel('Processes')
plt.ylabel('Efficiency')
plt.title("Efficiencies of parallel program on different problem sizes")
plt.plot(x,y2["Half"],linestyle = 'dotted',label = 'Half')
plt.plot(x,y2["Original"])
plt.plot(x,y2["Double"],linestyle = 'dashed',label = 'Double')
plt.legend(['Half','Original','Double']);

# %% [markdown]
# # Efficiency - Processes Relation
# > Half seems to be decreasing rapidly in efficiency as number of processes increase indicating inverse relationship,
# Original showcases the same signs as Half, where efficiency decreases with increasing the number of processes but with a lower degree of effect,
# Double experience low decrease in efficiency by increasing in number of processes

# %%
# !jupyter nbconvert Untitled.ipynb --to slides --post serve  --no-input --no-prompt
